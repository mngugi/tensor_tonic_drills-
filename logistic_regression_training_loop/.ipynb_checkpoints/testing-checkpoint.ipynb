# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyDrOxWc8kngTTPCS26SZFa0fMNn9w16p7E"

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?"
)

print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) doesn't "think" the way a human does. Instead, it **recognizes patterns in massive amounts of data** and uses those patterns to make predictions or decisions.
#
# Here is a breakdown of how it works, from the basic concept to the complex tech.
#
# ---
#
# ### 1. The Core Shift: From Rules to Learning
# To understand AI, you have to understand how it differs from traditional computer programming:
#
# *   **Traditional Programming:** A human writes specific "If/Then" rules. *Example: "If the user types 'Hello,' then reply 'Hi'."* If the user types "Hey," the computer gets stuck unless a human wrote a rule for that, too.
# *   **AI (Machine Learning):** We give the computer a goal and a massive pile of data, and **the computer figures out the rules itself.** *Example: You show a computer 10,000 pictures of cats. It learns to recognize the shapes and textures that define a "cat" without you ever explaining what whiskers are.*
#
# ### 2. The "Brain" of AI: Neural Networks
# Modern AI uses a structure called a **Neural Network**, which is loosely inspired by the human brain.
#
# *   **Neurons (Nodes):** These are little pockets of mathematical calculations.
# *   **Layers:** A neural network has many layers. The first layer sees raw data (like pixels in a photo), and each subsequent layer identifies more complex features (lines $\rightarrow$ circles $\rightarrow$ eyes $\rightarrow$ a face).
# *   **Weights and Biases:** These are like "volume knobs" inside the AI. When the AI makes a mistake, it turns the knobs down on the path that led to the wrong answer and turns them up on the path that would have led to the right one.
#
# ### 3. The Three Stages of AI Development
#
# #### Stage A: Data Collection
# AI is only as good as its "textbooks." To build a language AI (like ChatGPT), developers feed it almost everything on the public internet—books, articles, code, and conversations.
#
# #### Stage B: Training (The Learning Phase)
# This is where the heavy lifting happens. Using massive amounts of computing power:
# 1.  The AI makes a guess (e.g., "The cat sat on the ___").
# 2.  It compares its guess to the actual data (The answer was "mat").
# 3.  If it was wrong, it uses a process called **Backpropagation** to adjust its internal "knobs" (weights) to be more accurate next time.
# 4.  It repeats this billions of times until it becomes highly accurate.
#
# #### Stage C: Inference (The Using Phase)
# Once the AI is trained, its "knobs" are locked in place. When you ask it a question, it runs your prompt through its finished mathematical model and produces an answer based on the patterns it learned.
#
# ### 4. How Generative AI (like ChatGPT) works
# Generative AI is a specific type of AI called a **Large Language Model (LLM)**.
#
# It doesn't "know" facts; it is a **statistical prediction engine.** When you ask it a question, it is essentially asking itself: *"Based on all the text I have ever read, what is the most statistically likely word to follow the previous word?"*
#
# It builds sentences one word at a time, predicting the next piece of the puzzle based on the context of the words that came before.
#
# ### 5. Summary: The Recipe for AI
# To make AI work, you need three things:
# 1.  **Algorithms:** The mathematical formulas (the "logic").
# 2.  **Data:** The "fuel" the AI learns from.
# 3.  **Compute Power:** The massive "engines" (GPUs) required to process the math.
#
# **In short:** AI works by turning information (images, text, or sound) into numbers, finding the mathematical relationships between those numbers, and using those relationships to guess what comes next.

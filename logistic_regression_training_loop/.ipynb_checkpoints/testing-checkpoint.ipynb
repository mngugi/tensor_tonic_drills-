# %%
# testing the API key 
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyBcFckFgSOCEDCQvb9nn-tYez_CnND4o8M"

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?"
)

print(response.text)
# Out:
# At its simplest level, AI works by **finding patterns in massive amounts of data.**
#
# Unlike traditional computer programs, which follow a strict list of "if-then" rules written by humans, AI "learns" how to perform a task by analyzing examples.
#
# Here is a breakdown of how that process works, from the data to the final result.
#
# ---
#
# ### 1. The Fuel: Data
# AI needs examples to learn. If you want an AI to recognize a cat, you don’t give it a definition of a cat; you give it 10 million photos of cats. This data can be text, images, sensor readings, or numbers.
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the most common type of AI today. It is the method used to "train" the computer.
# *   **Supervised Learning:** You give the AI labeled data (e.g., a photo labeled "cat"). The AI tries to guess what’s in the photo, and if it’s wrong, you give it the correct answer so it can adjust.
# *   **Unsupervised Learning:** You give the AI raw data and ask it to find patterns on its own (e.g., "group these 1,000 customers into three categories based on their shopping habits").
#
# ### 3. The Brain: Neural Networks
# Modern AI (like ChatGPT or Midjourney) uses **Deep Learning**, which relies on "Neural Networks." These are mathematical structures inspired by the human brain.
#
# *   **Layers:** A neural network consists of layers of "nodes" (software versions of neurons).
# *   **Weights and Biases:** When data passes through these layers, the AI assigns a "weight" (importance) to certain features.
#     *   *Example:* If identifying a bird, the AI might learn that "has feathers" has a high weight, while "is blue" has a lower weight (since not all birds are blue).
# *   **Iteration:** The AI processes the data millions of times, constantly turning "dials" (weights) until its output matches reality.
#
# ### 4. The Process: Training vs. Inference
# There are two distinct phases in an AI’s life:
# 1.  **Training:** This is the "schooling" phase. It requires massive amounts of computing power. The AI looks at data, makes mistakes, and corrects its internal math.
# 2.  **Inference:** Once trained, the AI is "deployed." When you ask ChatGPT a question, it isn't "learning" from you in real-time in the same way; it is using its finished mathematical model to predict the best answer. This is called **Inference**.
#
# ### 5. How Generative AI (like ChatGPT) works
# Generative AI is a specific type of AI that creates new content.
# *   **Probability:** It doesn't "know" facts; it knows **probability**. When you ask it a question, it calculates which word is most likely to come after the previous one based on all the text it has ever read.
# *   **Transformers:** This is the specific technology (the "T" in GPT) that allows the AI to understand the *context* of a sentence. It knows that in the sentence "The bank of the river," the word "bank" means land, not a financial institution.
#
# ---
#
# ### An Analogy: Learning to Play Hit-the-Target
# Imagine a person wearing a blindfold trying to throw a ball at a target.
# *   **Traditional Programming:** You give the person a specific mathematical formula for the angle and strength of the throw.
# *   **AI (Machine Learning):** The person throws the ball randomly. A coach yells "Too far left!" or "Too short!" The person adjusts their movement slightly and throws again. After 10,000 throws, the person "knows" exactly how to hit the target, even though they can't see it and weren't given a formula.
#
# ### Summary
# AI doesn't "think" or have "consciousness." It is **advanced statistics.** It turns the world into numbers, calculates the patterns between those numbers, and uses those patterns to predict what should come next—whether that’s the next word in a sentence, the next move in a chess game, or identifying a tumor in an X-ray.

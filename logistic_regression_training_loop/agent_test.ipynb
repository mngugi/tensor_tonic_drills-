# %%
import os
from IPython.display import Markdown, display
import pandas as pd

# ✅ New LangChain message import
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

# Set your API key (never share publicly)
os.environ["GOOGLE_API_KEY"] = "AIzaSyDdPBClmlFiKrTnb0rsGiFfnXhtUDQY-4Q"

# Initialize the model
model = ChatGoogleGenerativeAI(model="models/gemini-2.5-pro")

# Example: send a message
message = HumanMessage(content="Hello from LangChain + Google Gemini 2.5-pro!")
response = model.invoke([message])

# Display the model output in notebook
display(Markdown(f"**Model says:** {response.content}"))

message = HumanMessage(
    content="Translate this sentence from English "
    "to French and Spanish. I like red cars and "
    "blue houses, but my dog is yellow."
)

# Invoke the model
response = model.invoke([message])

# Display output
display(Markdown(f"**Model says:** {response.content}"))

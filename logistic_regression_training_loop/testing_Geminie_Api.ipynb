# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from google import genai
# ----> 3 client = genai.Client()
#       5 response = client.models.generate_content(
#       6     model="gemini-3-flash-preview",
#       7     contents="How does AI work?"
#       8 )
#       9 print(response.text)
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/client.py:426, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     423   else:
#     424     http_options = HttpOptions(base_url=base_url)
# --> 426 self._api_client = self._get_api_client(
#     427     vertexai=vertexai,
#     428     api_key=api_key,
#     429     credentials=credentials,
#     430     project=project,
#     431     location=location,
#     432     debug_config=self._debug_config,
#     433     http_options=http_options,
#     434 )
#     436 self._aio = AsyncClient(self._api_client)
#     437 self._models = Models(self._api_client)
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/client.py:474, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     457 if debug_config and debug_config.client_mode in [
#     458     'record',
#     459     'replay',
#     460     'auto',
#     461 ]:
#     462   return ReplayApiClient(
#     463       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     464       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    471       http_options=http_options,
#     472   )
# --> 474 return BaseApiClient(
#     475     vertexai=vertexai,
#     476     api_key=api_key,
#     477     credentials=credentials,
#     478     project=project,
#     479     location=location,
#     480     http_options=http_options,
#     481 )
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:690, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     688 else:  # Implicit initialization or missing arguments.
#     689   if not self.api_key:
# --> 690     raise ValueError(
#     691         'Missing key inputs argument! To use the Google AI API,'
#     692         ' provide (`api_key`) arguments. To use the Google Cloud API,'
#     693         ' provide (`vertexai`, `project` & `location`) arguments.'
#     694     )
#     695   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     696   self._http_options.api_version = 'v1beta'
#
# ValueError: Missing key inputs argument! To use the Google AI API, provide (`api_key`) arguments. To use the Google Cloud API, provide (`vertexai`, `project` & `location`) arguments.
